# %% [markdown]
# <a href="https://colab.research.google.com/github/piyushk4732/cognitive_computing/blob/main/cognitive_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L = [int(digit) * 10 for digit in "1024170216"]
print(L)
L.append(100)
print(L)
L.insert(2, 200)
print(L)
L.remove(40)
print(L)
L.pop()
print(L)
L.sort()
print(L)
L.sort(reverse=True)
print(L)
print(L[:3])
print(L[-3:])
average = sum(L) / len(L)
new_list = [x for x in L if x > average]
print(average)
print(new_list)
# Out:
# [10, 0, 20, 40, 10, 70, 0, 20, 10, 60]
# [10, 0, 20, 40, 10, 70, 0, 20, 10, 60, 100]
# [10, 0, 200, 20, 40, 10, 70, 0, 20, 10, 60, 100]
# [10, 0, 200, 20, 10, 70, 0, 20, 10, 60, 100]
# [10, 0, 200, 20, 10, 70, 0, 20, 10, 60]
# [0, 0, 10, 10, 10, 20, 20, 60, 70, 200]
# [200, 70, 60, 20, 20, 10, 10, 10, 0, 0]
# [200, 70, 60]
# [10, 0, 0]
# 40.0
# [200, 70, 60]

# %%
L = [10, 0, 20, 40, 10, 70, 0, 20, 10, 60]
scores = tuple(L[:8])
print(scores)
highest = max(scores)
highest_index = scores.index(highest)
lowest = min(scores)
lowest_count = scores.count(lowest)
print("Highest:", highest)
print("Highest index:", highest_index)
print("Lowest:", lowest)
print("Lowest count:", lowest_count)
reversed_scores = list(scores[::-1])
print("Reversed:", reversed_scores)
user_score = int(input("Enter a score: "))
if user_score in scores:
    print("First occurrence index:", scores.index(user_score))
else:
    print("Score not present")
# iv. modify tuple
# scores[0] = 100
# TypeError occurs because tuples are immutable.


first_score, second_score, *remaining_scores = scores

print("First score:", first_score)
print("Second score:", second_score)
print("Remaining scores:", remaining_scores)
# Out:
# (10, 0, 20, 40, 10, 70, 0, 20)
# Highest: 70
# Highest index: 5
# Lowest: 0
# Lowest count: 2
# Reversed: [20, 0, 70, 10, 40, 20, 0, 10]
# Enter a score: 40
# First occurrence index: 3
# First score: 10
# Second score: 0
# Remaining scores: [20, 40, 10, 70, 0, 20]

# %%
import random
random.seed(1024170216)
numbers = [random.randint(100, 900) for i in range(100)]
print(numbers)
odd_numbers = [x for x in numbers if x % 2 != 0]
print(len(odd_numbers))
print(odd_numbers)
even_numbers = [x for x in numbers if x % 2 == 0]
print(len(even_numbers))
print(even_numbers)
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True
prime_numbers = [x for x in numbers if is_prime(x)]
print(len(prime_numbers))
print(prime_numbers)
most_frequent = max(numbers, key=numbers.count)
frequency = numbers.count(most_frequent)
print(most_frequent)
print(frequency)
# Out:
# [323, 721, 161, 527, 555, 820, 851, 694, 582, 351, 772, 101, 102, 809, 635, 322, 576, 759, 725, 634, 690, 308, 167, 810, 447, 275, 715, 373, 486, 430, 704, 378, 642, 798, 753, 654, 796, 540, 820, 562, 859, 488, 812, 649, 660, 767, 108, 468, 554, 180, 359, 231, 804, 858, 813, 199, 509, 502, 735, 764, 729, 679, 205, 448, 857, 143, 777, 477, 900, 248, 143, 793, 378, 420, 205, 522, 827, 175, 424, 344, 317, 513, 283, 695, 769, 148, 384, 340, 143, 299, 493, 211, 177, 189, 337, 499, 772, 345, 515, 181]
# 55
# [323, 721, 161, 527, 555, 851, 351, 101, 809, 635, 759, 725, 167, 447, 275, 715, 373, 753, 859, 649, 767, 359, 231, 813, 199, 509, 735, 729, 679, 205, 857, 143, 777, 477, 143, 793, 205, 827, 175, 317, 513, 283, 695, 769, 143, 299, 493, 211, 177, 189, 337, 499, 345, 515, 181]
# 45
# ...

# %%
digits=[1, 0, 2, 4, 1, 7, 0, 2]
A = {digit * 7 for digit in digits}
B = {digit * 9 for digit in digits}
print(A)
print(B)
union = A.union(B)
print(union)
intersection = A.intersection(B)
print(intersection)
A_minus_B = A.difference(B)
B_minus_A = B.difference(A)
print(A_minus_B)
print(B_minus_A)
symmetric_difference = A.symmetric_difference(B)
print(symmetric_difference)
print(A.issubset(B))
print(B.issuperset(A))
x = int(input("Enter a value X: "))
A.discard(x)
print("Set A after discard:", A)
